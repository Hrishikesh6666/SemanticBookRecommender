# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma  # Import Chroma from langchain.vectorstores
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 4
#       2 from langchain_text_splitters import CharacterTextSplitter
#       3 from langchain_openai import OpenAIEmbeddings
# ----> 4 from langchain.vectorstores import Chroma  # Import Chroma from langchain.vectorstores
#       5 from langchain_chroma import Chroma
#
# ImportError: cannot import name 'Chroma' from 'langchain.vectorstores' (D:\LLM_BookRecommender\.venv\Lib\site-packages\langchain\vectorstores\__init__.py)

# %%
from dotenv import load_dotenv
load_dotenv()  # Load environment variables from .env file

import os
hf_api_key = os.getenv("HUGGINGFACEHUB_API_TOKEN")

# %%
import pandas as pd

books = pd.read_csv("Books_cleaned.csv")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5193  9788172235222  8172235224
# 5194  9788173031014  8173031010
# 5195  9788179921623  817992162X
# 5196  9788185300535  8185300534
# 5197  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5193                                  Mistaken Identity
# 5194                                Journey to the East
# 5195  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
books["tagged_description"]
# Out:
# 0       9780002005883: A NOVEL THAT READERS and critic...
# 1       9780002261982: A new 'Christie for Christmas' ...
# 2       9780006178736: A memorable, mesmerizing heroin...
# 3       9780006280897: Lewis' work on the nature of lo...
# 4       9780006280934: "In The Problem of Pain, C.S. L...
#                               ...
# 5193    9788172235222: On A Train Journey Home To Nort...
# 5194    9788173031014: This book tells the tale of a m...
# 5195    9788179921623: Wisdom to Create a Life of Pass...
# 5196    9788185300535: This collection of the timeless...
# 5197    9789027712059: Since the three volume edition ...
# Name: tagged_description, Length: 5198, dtype: object

# %%
books["tagged_description"].to_csv("tagged_description.txt",
                                   sep = "\n",
                                   index = False,
                                   header = False)

# %%
import os
print(os.path.exists("tagged_description.txt"))  # Should print True
# Out:
# True

# %%
# Load text file
raw_documents = TextLoader("tagged_description.txt", encoding="utf-8").load()

# Ensure the file has data
if not raw_documents:
    raise ValueError("Loaded file is empty!")

# Split text into chunks (adjust size as needed)
text_splitter = CharacterTextSplitter(chunk_size=0, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)

print(f"Total chunks created: {len(documents)}")
# Out:
# Created a chunk of size 1169, which is longer than the specified 0
# Created a chunk of size 1215, which is longer than the specified 0
# Created a chunk of size 374, which is longer than the specified 0
# Created a chunk of size 310, which is longer than the specified 0
# Created a chunk of size 484, which is longer than the specified 0
# Created a chunk of size 483, which is longer than the specified 0
# Created a chunk of size 961, which is longer than the specified 0
# Created a chunk of size 189, which is longer than the specified 0
# Created a chunk of size 844, which is longer than the specified 0
# Created a chunk of size 297, which is longer than the specified 0
# Created a chunk of size 198, which is longer than the specified 0
# Created a chunk of size 882, which is longer than the specified 0
# Created a chunk of size 1089, which is longer than the specified 0
# Created a chunk of size 1190, which is longer than the specified 0
# ...

# %%
documents[35]
# Out:
# Document(metadata={'source': 'tagged_description.txt'}, page_content="9780007117536: On the eve of the next Space Shuttle mission, a divided family comes together... Warm, witty and wise, All Families Are Psychotic is Coupland at the very top of his form: 'Irresistibly hilarious, unique and wonderful' Independent on Sunday In a cheap motel an hour from Cape Canaveral, Janet Drummond takes her medication, and does a rapid tally of the whereabouts of her children. Wade has spent the night in jail; suicidal Bryan is due to arrive at any moment with his vowel-free girlfriend, Shw; and then there is Sarah, 'a bolt of lightning frozen in midflash' -- here in Orlando to be the star of Friday's shuttle mission. With Janet's ex-husband and his trophy wife also in town, Janet spends a moment contemplating her family, and where it all went wrong. Or did it?")

# %%
# !pip install chromadb
# Out:
# ...
#   Using cached chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# ...
#   Using cached uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached posthog-3.11.0-py2.py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached onnxruntime-1.20.1-cp312-cp312-win_amd64.whl.metadata (4.7 kB)
# ...
#   Using cached opentelemetry_api-1.29.0-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl.metadata (2.2 kB)
# ...

# %%
from dotenv import load_dotenv
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

import os

# Load environment variables from .env file
load_dotenv()

# Use HuggingFace embeddings in LangChain
hf_embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Assuming 'documents' is your list of documents
db_books = Chroma.from_documents(
    documents,
    embedding=hf_embeddings  # Use Hugging Face embeddings
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\LLM_BookRecommender\.venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:83, in Chroma.__init__(self, collection_name, embedding_function, persist_directory, client_settings, collection_metadata, client, relevance_score_fn)
#      82 try:
# ---> 83     import chromadb
#      84     import chromadb.config
#
# ModuleNotFoundError: No module named 'chromadb'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 14
#      11 hf_embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
#      13 # Assuming 'documents' is your list of documents
# ---> 14 db_books = Chroma.from_documents(
#      15     documents,
# ...
